# %%
import osmium

# %%
handler = osmium.SimpleHandler()

# %%
handler.apply_file("./data/unterfranken-251216.osm.pbf")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 handler.apply_file("./data/unterfranken-251216.osm.pbf")
#
# File /run/media/feds/2309E02F47F328C5/EAGLE/Urban_AZwick/FinalMeasurements/.venv/lib/python3.13/site-packages/osmium/simple_handler.py:61, in SimpleHandler.apply_file(self, filename, locations, idx, filters)
#      50 def apply_file(self, filename: Union[str, 'os.PathLike[str]', File],
#      51                locations: bool = False, idx: str = 'flex_mem',
#      52                filters: List['HandlerLike'] = []) -> None:
#      53     """ Apply the handler to the given file. If locations is true, then
#      54         a location handler will be applied before, which saves the node
#      55         positions. In that case, the type of this position index can be
#    (...)     59         be executed.
#      60     """
# ...

# %% [markdown]
# # cmdline

# %%
# !osm2pgsql -d buildings -O flex -S 3dbuildings.lua ./data/unterfranken-251216.osm.pbf
# Out:
# 2025-12-17 14:53:44  osm2pgsql version 2.2.0
# 2025-12-17 14:53:44  ERROR: Connecting to database failed (context=check): connection to server on socket "/var/run/postgresql/.s.PGSQL.5432" failed: No such file or directory
# 	Is the server running locally and accepting connections on that socket?
# .
